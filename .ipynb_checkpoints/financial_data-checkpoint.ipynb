# %%
import pandas as pd
import pandas_datareader as pdr
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta
# %matplotlib notebook

# %%
ticker = "AAPL"
start = datetime.now() - timedelta(days=365)
data = pdr.get_data_yahoo(ticker, start)
data.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-06-02  125.239998  124.050003  124.279999  125.059998  59278900.0
# 2021-06-03  124.849998  123.129997  124.680000  123.540001  76229200.0
# 2021-06-04  126.160004  123.849998  124.070000  125.889999  75169300.0
# 2021-06-07  126.320000  124.830002  126.169998  125.900002  71057600.0
# 2021-06-08  128.460007  126.209999  126.599998  126.739998  74403800.0
#
#              Adj Close
# Date
# 2021-06-02  124.349564
# 2021-06-03  122.838203
# 2021-06-04  125.174850
# 2021-06-07  125.184792
# 2021-06-08  126.020012

# %%
data["%-chg"] = data["Close"].pct_change()
data.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-06-02  125.239998  124.050003  124.279999  125.059998  59278900.0
# 2021-06-03  124.849998  123.129997  124.680000  123.540001  76229200.0
# 2021-06-04  126.160004  123.849998  124.070000  125.889999  75169300.0
# 2021-06-07  126.320000  124.830002  126.169998  125.900002  71057600.0
# 2021-06-08  128.460007  126.209999  126.599998  126.739998  74403800.0
#
#              Adj Close     %-chg
# Date
# 2021-06-02  124.349564       NaN
# 2021-06-03  122.838203 -0.012154
# 2021-06-04  125.174850  0.019022
# 2021-06-07  125.184792  0.000079
# 2021-06-08  126.020012  0.006672

# %%
data["Log returns"] = np.log(data["Close"]/data["Close"].shift())

# %%
data.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-06-02  125.239998  124.050003  124.279999  125.059998  59278900.0
# 2021-06-03  124.849998  123.129997  124.680000  123.540001  76229200.0
# 2021-06-04  126.160004  123.849998  124.070000  125.889999  75169300.0
# 2021-06-07  126.320000  124.830002  126.169998  125.900002  71057600.0
# 2021-06-08  128.460007  126.209999  126.599998  126.739998  74403800.0
#
#              Adj Close     %-chg  Log returns
# Date
# 2021-06-02  124.349564       NaN          NaN
# 2021-06-03  122.838203 -0.012154    -0.012229
# 2021-06-04  125.174850  0.019022     0.018844
# 2021-06-07  125.184792  0.000079     0.000079
# 2021-06-08  126.020012  0.006672     0.006650

# %%
volatility = data["Log returns"].std()*252**.5
volatility
# Out:
# 0.28157069929924805

# %%
str_vol = str(round(volatility, 4)*100)
str_vol
# Out:
# '28.16'

# %%
fix , ax = plt.subplots()
data["Log returns"].hist(ax=ax, bins=50, alpha=0.6, color="blue")
ax.set_xlabel("Log return")
ax.set_ylabel("Freq of log return")
ax.set_title("AAPL volatility: " + str_vol + "%")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'AAPL volatility: 28.16%')

# %%
data["Rolling avarage"] = data["Close"].rolling(10).mean()
# Out:
# Date
# 2021-06-02           NaN
# 2021-06-03    124.299999
# 2021-06-04    124.715000
# 2021-06-07    125.895000
# 2021-06-08    126.320000
#                  ...
# 2022-05-25    140.440002
# 2022-05-26    142.150002
# 2022-05-27    146.709999
# 2022-05-31    149.239998
# 2022-06-01    148.775002
# Name: Close, Length: 253, dtype: float64
